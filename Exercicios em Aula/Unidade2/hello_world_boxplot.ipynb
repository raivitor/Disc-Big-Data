# %%
import matplotlib.pyplot as plt
import pandas as pd

x = [[38946, 43420, 49191, 50430, 50557, 52580, 53595, 54135, 60181,10000000],
     [33219, 36254, 38801, 46335, 46840, 47596, 55130, 56863, 78070, 88830]]
df = pd.DataFrame(x, index=['Sample 1', 'Sample 2'])

## Show the mean in boxplot
#df.T.boxplot(vert=False, return_type='axes', showfliers=False, showmeans=True)

## showfliers=False removes outliers
df.T.boxplot(vert=False, return_type='axes', showfliers=False)

plt.subplots_adjust(left=0.25)
plt.show()

## transpose() transform df from 2x10 to 10x2 matrix
## describe() show statistical details of dataframe structure
df.transpose().describe()
# Out:
#            Sample 1      Sample 2
# count  1.000000e+01     10.000000
# mean   1.045304e+06  52793.800000
# std    3.146365e+06  18000.701849
# min    3.894600e+04  33219.000000
# 25%    4.950075e+04  40684.500000
# 50%    5.156850e+04  47218.000000
# 75%    5.400000e+04  56429.750000
# max    1.000000e+07  88830.000000
