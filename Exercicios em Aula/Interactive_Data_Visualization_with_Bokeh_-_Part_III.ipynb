# %% [markdown]
# # A basic histogram
#
# Create a simple histogram with the Histogram() function. Again we'll use the fertility data set to plot the distribution of female literacy around the world.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# Make the Histogram: p
p = Histogram(data, 'female literacy', title='Female Literacy', bins=40)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'


# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1e9a54d8-8e0f-4214-b73c-97e27d19f5fb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="877af1c0-f09e-43f1-ba6c-b06403c69fb6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("877af1c0-f09e-43f1-ba6c-b06403c69fb6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("877af1c0-f09e-43f1-ba6c-b06403c69fb6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '877af1c0-f09e-43f1-ba6c-b06403c69fb6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eaf8fa6a-ae71-474b-baff-456d2460b194":{"roots":{"references":[{"attributes":{"data_source":{"id":"eca522f9-34e5-4df4-a419-b11d8b426f3b","type":"ColumnDataSource"},"glyph":{"id":"5305464f-fb1e-467e-8463-297c947c32e1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e996c44a-5e94-4f9a-a16f-1520be6e1f01","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[12.600000, 14.785000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["[12.600000, 14.785000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000005],"x":["13.692499999999999"],"y":[0.5]}},"id":"2a559e84-35fd-4eb2-9e88-a4a6b206850d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5305464f-fb1e-467e-8463-297c947c32e1","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f4ea0f1b-8bbd-4310-a016-d418c58c10bf","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(14.785000, 16.970000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(14.785000, 16.970000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1849999999999987],"x":["15.8775"],"y":[0.5]}},"id":"aebef382-aea4-4999-be90-7309ab99ee3d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2a559e84-35fd-4eb2-9e88-a4a6b206850d","type":"ColumnDataSource"},"glyph":{"id":"f4ea0f1b-8bbd-4310-a016-d418c58c10bf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1361a94b-22ff-46a3-a205-49f9a1cea3b5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e61fd9e7-a2ee-4a83-808d-84ea1bd53865","type":"Rect"},{"attributes":{"callback":null,"end":51.7},"id":"2d420229-d7c1-4a36-b298-b08639487785","type":"Range1d"},{"attributes":{"data_source":{"id":"c25b9c00-9749-4076-9805-8bcf7e2a11f9","type":"ColumnDataSource"},"glyph":{"id":"8341f1ba-d9d3-4a3f-b8fd-3a158a8c607f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5103dccf-53ef-4aef-ba4a-a82ad2392b61","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(97.815000, 100.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[47.0],"label":["(97.815000, 100.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000023],"x":["98.9075"],"y":[23.5]}},"id":"95fa739a-2d22-4262-9fac-04c8e9f9e09e","type":"ColumnDataSource"},{"attributes":{"axis_label":"Female Literacy (% population)","formatter":{"id":"c10fc5b9-427b-4e8b-a006-95b06fa9e43e","type":"BasicTickFormatter"},"plot":{"id":"14baed10-7b2f-4a15-9f41-a3b88689c337","subtype":"Chart","type":"Plot"},"ticker":{"id":"1daa3ca3-dc7e-446e-8879-966aa0841db3","type":"BasicTicker"}},"id":"e7a09b2b-43f7-4fd8-bc0e-d53b819b4570","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc1c65c4-3ce3-4f61-bcde-a40da700c964","type":"Rec ...

# %% [markdown]
# # Generating multiple histograms at once
#
# Let's make separate histograms, each with 10 bins for each of the 6 continents.
#
# To do this with Bokeh charts we pass a column name to the the **color** parameter of the **Histogram()** function. In this case, the **'Continent'** column contains the continent abbreviation that we'll use to group the female literacy values in each of the 6 continents.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# Make a Histogram: p
p = Histogram(data, 'female literacy', title='Female Literacy',
              color='Continent', legend='top_left', bins=10)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'


# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d9ca21b-cd23-43c6-861b-a3e02e949ab5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0580124e-a83d-404f-ba6e-1713806954d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0580124e-a83d-404f-ba6e-1713806954d5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0580124e-a83d-404f-ba6e-1713806954d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0580124e-a83d-404f-ba6e-1713806954d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"91618df1-55a9-4ed6-be74-9934a3c1a06c":{"roots":{"references":[{"attributes":{"data_source":{"id":"d928cba9-7e2e-4133-acf9-bc19077cb062","type":"ColumnDataSource"},"glyph":{"id":"8b6e9441-3d20-43fb-836b-63897b8cbb24","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a108866c-dc29-4daf-9215-651ea30b07c0","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fa60e6db-0b8d-41f3-9104-18473ee6eab6","type":"ColumnDataSource"},"glyph":{"id":"6137a688-0ce7-456f-8e61-175c788428fa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4eb383bc-c8b6-46a0-91c7-b2a5de56b3a3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(99.290000, 100.000000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[10.0],"label":["(99.290000, 100.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7099999999999937],"x":["99.64500000000001"],"y":[5.0]}},"id":"d928cba9-7e2e-4133-acf9-bc19077cb062","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(94.320000, 95.030000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"label":["(94.320000, 95.030000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7099999999999937],"x":["94.675"],"y":[0.0]}},"id":"fa60e6db-0b8d-41f3-9104-18473ee6eab6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6137a688-0ce7-456f-8e61-175c788428fa","type":"Rect"},{"attributes":{"data_source":{"id":"f29a6fae-b091-4d00-9ac4-07fa4329737e","type":"ColumnDataSource"},"glyph":{"id":"0f2ca2f2-a1b5-42d7-a4d5-8add506fb1d4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6ebebd37-574e-4428-a47c-bb6f6fd376c9","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":102.815,"start":9.784999999999998},"id":"6b1d986c-4939-4332-b25d-d73856ca9395","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fe4f60e9-61de-4f1f-a67b-23f72fd6a855","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[15.100000, 23.100000]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[5.0],"label":["[15.100000, 23.100000]"],"line_alpha":[1.0],"line_color":["black"],"width":[8.000000000000002],"x":["19.1"],"y":[2.5]}},"id":"52a38375-a26e-46f6-bf21-64e085fd1445","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(93.610000, 94.320000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[0.0],"label":["(93.610000, 94.320000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.710000000000008],"x":["93.965"],"y":[0.0]}},"id":"f29a6fae-b091-4d00-9ac4-07fa4329737e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d25d4e8a-eb1d-4bbe-b18c-b9c1d91e7631","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"fiel ...

# %% [markdown]
# # A basic box plot
#
# In this exercise, you'll make a box plot of female literacy per continent by setting **values='female_literacy'** and **label='Continent'** with the **BoxPlot()** function.

# %%
# Import BoxPlot, output_notebook, and show from bokeh.charts
from bokeh.charts import BoxPlot, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# Make a box plot: p
p = BoxPlot(data, values='female literacy', label='Continent',
             title='Female Literacy (grouped by Continent)',
             legend='bottom_right')

# Set the y axis label
p.yaxis.axis_label='Female literacy (% population)'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="91c8f424-cd54-4d93-b8af-b458937010ba">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="74d8191f-ef7c-40b2-989b-e46101191c7c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("74d8191f-ef7c-40b2-989b-e46101191c7c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("74d8191f-ef7c-40b2-989b-e46101191c7c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '74d8191f-ef7c-40b2-989b-e46101191c7c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e1448732-4243-4447-99cd-19495c467e14":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["NAM"],"chart_index":[{"Continent":"NAM"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Continent":"NAM"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["NAM"],"y":[99.0]}},"id":"a479ad17-5a8e-46c0-a948-8b0e74d727a8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6586167a-25ed-473e-a5ee-2ac8fd0b414f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c070cd6-1ec0-44a6-88f6-37bc843fdb19","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"93015070-9cc3-4762-9d85-61526d3be036","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b8bc5a88-d5e0-4ef7-a39e-03e729c1bbc2","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"1afb9c42-72af-4cb3-a04f-8f410ff91204","type":"Segment"},{"attributes":{"data_source":{"id":"2311058b-3930-49e3-9a2e-42a7f0b85694","type":"ColumnDataSource"},"glyph":{"id":"f30fc336-0740-4a05-bba4-25600222738f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a7441b5b-dbc2-4b05-a62f-a1b258c6b6c2","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"a7ef1ff7-5ea1-48e4-889e-77b9824e54dd","subtype":"Chart","type":"Plot"},"ticker":{"id":"9b6cfebb-cffd-4615-8e68-119b98016f00","type":"BasicTicker"}},"id":"0c1df09b-1c67-4f78-915c-29e645d3c55b","type":"Grid"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"351e4c56-4fce-4751-9dc2-d0ba2d9187a6","type":"Segment"},{"attributes":{"data_source":{"id":"a479ad17-5a8e-46c0-a948-8b0e74d727a8","type":"ColumnDataSource"},"glyph":{"id":"6586167a-25ed-473e-a5ee-2ac8fd0b414f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"eb8f5f6b-b41f-4703-acd1-b253ad0d2556","type":"GlyphRenderer"},{"attributes":{},"id":"0f26b7df-90fa-4974-83aa-be4a90c30b53","type":"BasicTickFormatter"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"4d6e71b8-f9ab-422e-88f7-9a90448f162c","type":"Segment"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["OCE"],"chart_index":[{"Continent":"OCE"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[9.625],"label":[{"Continent":"OCE"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["OCE"],"y":[93.8125]}},"id":"43ce9591-8ab2-4615-b289-b4cccb77dd6a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4cac6941-c3f6-4ee6-baa4-b98081250e82","type":"ColumnDataSource"},"glyph":{"id":"7aa03d15-e327-4ec2-bafc-6b3eadc16fc1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"471e77d4-9f29-451d-84f5-12b24ebd7d22","type":"GlyphRenderer"},{"attributes":{},"id":"6b5d2f94-40 ...

# %% [markdown]
# # Color different groups differently
#
# Like the **Histogram()** function, we can use the color parameter of the **BoxPlot()** function to color the box plot of each continent separately.
#
# In this exercise, you'll distinguish between the six continents by setting set the color parameter of the **BoxPlot()** function to **'Continent'**.

# %%
# Make a box plot: p
p = BoxPlot(data, values='female literacy', label='Continent', color='Continent',
             title='Female Literacy (grouped by Continent)',
             legend='bottom_right')

# Set the y axis label
p.yaxis.axis_label='Female literacy (% population)'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9eea847f-1fd9-476c-a686-65c31c8ba77c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51fd8daa-4716-4c68-b23b-caf35580a2a8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("51fd8daa-4716-4c68-b23b-caf35580a2a8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51fd8daa-4716-4c68-b23b-caf35580a2a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51fd8daa-4716-4c68-b23b-caf35580a2a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e41e7710-a712-4c0a-ab7c-dc2e3ef569a4":{"roots":{"references":[{"attributes":{"data_source":{"id":"3b592c97-d524-413e-ad09-b02abf83efac","type":"ColumnDataSource"},"glyph":{"id":"fec23f50-3f1e-4651-82db-09d5e0584d10","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ad136c83-9502-430e-802d-89a2c708ad96","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"7b42cfb5-3c30-49a2-93b6-16e41461470f","type":"Segment"},{"attributes":{"plot":{"id":"3956533f-9f3e-4995-b7cf-4a4f8bed5b02","subtype":"Chart","type":"Plot"}},"id":"7796fcb2-66af-42de-9c8c-b6049ba35237","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"2e7aeb64-f69b-4573-b434-7e3a4ec73edd","type":"ColumnDataSource"},"glyph":{"id":"60c4ea0e-1793-4e44-843f-df0195d3c281","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"64796a76-2572-43e3-adbf-dde99243e2e1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["LAT"],"chart_index":[{"Continent":"LAT"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[4.6499999999999915],"label":[{"Continent":"LAT"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["LAT"],"y":[94.475]}},"id":"2e7aeb64-f69b-4573-b434-7e3a4ec73edd","type":"ColumnDataSource"},{"attributes":{"label":{"value":"EUR"},"renderers":[{"id":"dc2dc5a0-729f-4fe9-893b-f8f9eb6a1e63","type":"GlyphRenderer"},{"id":"16b78203-bb16-4aec-a042-37af91f888e9","type":"GlyphRenderer"},{"id":"0002a08f-7aaf-4534-9212-26496e8dbb90","type":"GlyphRenderer"},{"id":"02e8d562-2146-4bf2-9594-c961df13cecd","type":"GlyphRenderer"}]},"id":"4f189c4e-8593-44f6-a175-cf6463309775","type":"LegendItem"},{"attributes":{},"id":"af8e0462-15e1-4f1e-821d-12d6318dbb52","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"3956533f-9f3e-4995-b7cf-4a4f8bed5b02","subtype":"Chart","type":"Plot"},"ticker":{"id":"8792466b-f063-4ffd-adf7-28c1990241b5","type":"BasicTicker"}},"id":"54c8f294-e7fe-403a-a0b8-e93eeb2764e4","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9ed9101-2377-4122-bff0-998a46673c07","type":"Rect"},{"attributes":{"plot":{"id":"3956533f-9f3e-4995-b7cf-4a4f8bed5b02","subtype":"Chart","type":"Plot"}},"id":"1367cc68-8fc6-439f-a601-cd9cd9c220c8","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["LAT"],"chart_index":[{"Continent":"LAT"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[6.5],"label":[{"Continent":"LAT"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["LAT"],"y":[88.9]}},"id":"c6fe5811-5076-4ac2-ad30-cdf3bd164b3d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"490436a7-073b-4822-b989-ee54d4bcb666","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9422f055-c13d-4dbe-9b8f-5bc8fc7d8dd6","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"e4951df4-a5d4-4e02-a16b-97efdbbdbc0a","type":"Segment"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"ov ...

# %% [markdown]
# # A basic scatter plot
#
#
# The high level Scatter in bokeh.charts is similar to marker plots from bokeh.plotting, but differs in important ways.
# - For drawing different markers automatically based on groups in the data.
# - To choose colors automatically based on groups in the data.
# - You want to work directly with Pandas DataFrame.
#
# In this exercise, you'll make a simple scatter plot of female literacy on the y axis and population on x axis.

# %%
# Import Scatter, output_notebook, and show from bokeh.charts
from bokeh.charts import Scatter, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')


# Make a scatter plot: p
p = Scatter(data, x='population', y='female literacy',
            title='Female Literacy vs Population')

# Set the x-axis label
p.xaxis.axis_label = 'Population'

# Set the y-axis label
p.yaxis.axis_label = 'Female Literacy'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe91d172-6e0d-4a4f-9aae-dbbc2285315c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3db36ae7-24bb-45d9-8167-78a7ed65c5ac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3db36ae7-24bb-45d9-8167-78a7ed65c5ac").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3db36ae7-24bb-45d9-8167-78a7ed65c5ac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3db36ae7-24bb-45d9-8167-78a7ed65c5ac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7535725d-b505-47f7-88ba-d0741c62f9c8":{"roots":{"references":[{"attributes":{"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"}},"id":"a65f4372-b607-4d31-8725-18d1a7b7d203","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"09fa457c-501f-4821-b74a-05474cf53662","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"}},"id":"2cc1bf52-dd79-41ff-8363-3a67ca5430a1","type":"ResetTool"},{"attributes":{"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"}},"id":"41114d82-d00e-465a-a2af-9cf6656bd78d","type":"HelpTool"},{"attributes":{"data_source":{"id":"7bafcbf3-31b0-4d8c-af07-d767a6e45fd6","type":"ColumnDataSource"},"glyph":{"id":"e57c3a22-254a-4b89-8827-d146c328e6a0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3cc581aa-7110-41f7-874a-5f1e9bb75870","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e57c3a22-254a-4b89-8827-d146c328e6a0","type":"Circle"},{"attributes":{},"id":"4183f9f7-d8e1-4989-8087-997977eec413","type":"BasicTicker"},{"attributes":{"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"},"ticker":{"id":"4183f9f7-d8e1-4989-8087-997977eec413","type":"BasicTicker"}},"id":"40e2ec4c-30e2-46b2-8ca7-cfe3bf985674","type":"Grid"},{"attributes":{"axis_label":"Female Literacy","formatter":{"id":"1131ad3c-541d-4cba-a49f-b916dd2d5047","type":"BasicTickFormatter"},"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"},"ticker":{"id":"767fb334-8b4c-4c8b-ba30-f0bc94f4dabf","type":"BasicTicker"}},"id":"9502504a-32fc-4190-97ad-166faf756964","type":"LinearAxis"},{"attributes":{},"id":"767fb334-8b4c-4c8b-ba30-f0bc94f4dabf","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c3668129-8513-420b-9a56-86a7d061fd10","subtype":"Chart","type":"Plot"},"ticker":{"id":"767fb334-8b4c-4c8b-ba30-f0bc94f4dabf","type":"BasicTicker"}},"id":"d583dc6b-ed19-43a5-a543-75d4c069a793","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1324655000,1139964932,304060000,227345082,191971506,166111487,160000128,151212254,141950000,127704000,106350434,90348437,86210781,82110097,81527172,80713434,73914260,71956322,67386383,64256635,62277432,61414062,59832179,49563019,48687000,48607000,46258200,45555716,45012096,42483923,41347723,39882980,38765312,38125759,34373426,33311400,31656865,31605616,30711152,29021099,28836700,28809526,27935000,27313700,27014337,24645686,23818753,23350927,22917485,22382533,21513622,20591302,20581290,20156204,19110941,19088385,18020668,16803952,16 ...
