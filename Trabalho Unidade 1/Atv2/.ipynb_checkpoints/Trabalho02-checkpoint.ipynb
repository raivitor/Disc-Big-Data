# %% [markdown]
# # Exercise
#
# - Use the previous knowledge to extract information from the European Environment Agency (EEA).
# - Adopt the monitoring co2 emissions [dataset](http://www.eea.europa.eu/data-and-maps/data/co2-cars-emission-11) (**Monitoring of CO2 emissions from passenger cars - Data 2015 - Final data**)

# %%
#%%timeit
import numpy as np
import pandas as pd
from pprint import pprint
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

# %%
pd_cars = pd.read_csv("versao3.csv", low_memory = False, error_bad_lines = False, warn_bad_lines = False, encoding = "utf-8")
fuelfilter = ['E85', 'DIESEL-ELECTRIC', 'PETROL-ELECTRIC', 'ELECTRIC', 'NG-BIOMETHANE', 'LPG', 'PETROL', 'DIESEL']

# %%
def Filter():
    df_filter = []
    for index, row in pd_cars.iterrows():
        try:
            if (str(row["ep (KW)"]).isnumeric()) and (str(row["e (g/km)"]).isnumeric()) and fuelfilter.index(str(row["Ft"])):
                df_filter.append(row)
        except:
            continue

    df_filter = pd.DataFrame(df_filter)        
    len(df_filter)
    df_filter.to_csv("versao3.csv",  encoding = "utf-8")

#Filter()

# Return array 2D
def CountValues(index, valMin):
    listReturn = []
    for i, row in df_filter[index].value_counts().sort_values().iteritems():
        if(row > valMin):
            listReturn.append([i, row])
    np_listReturn = np.array(listReturn)     
    return np_listReturn

# %% [markdown]
# mh é um array 2d que fica o nome das fabricantes e a quantidade de carros que elas fizeram.
# Esse array tem 31 fabricantes e 429.504 carros. Todas as fabricantes tem mais que 1000 carros produzidos.

# %%
np_mh = CountValues("Mh", 1000)
#print(np_mh[:,1])

data = {
    'fuelName': np_mh[:,0],
    'fuelQuant': np_mh[:,1]
}

# x-axis labels pulled from the fuelName column, stacking labels from sample column
bar = Bar(data, values='fuelQuant', label='fuelName', agg="mean",
          title="Python fuelName Sampling", legend=False, plot_width=900)


output_notebook()
show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32e79bc8-f78a-4ac1-b258-29575b36f1c8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ad3be0e9-9823-4fe2-9bd2-6171a37bbb56"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ad3be0e9-9823-4fe2-9bd2-6171a37bbb56").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad3be0e9-9823-4fe2-9bd2-6171a37bbb56");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad3be0e9-9823-4fe2-9bd2-6171a37bbb56' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8a44ea68-6999-49ec-adf5-34bbddff6f37":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1df03c7e-6a37-4882-a82e-312c0031b821","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7ae7d5ef-7a26-4c1f-bbed-625fc7d23ef3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"512b0792-62ac-457b-b62b-b596aa0fcd34","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"fuelName":"OPEL"}],"color":["#f22c40"],"fill_alpha":[0.8],"fuelName":["OPEL"],"height":[24848.0],"label":[{"fuelName":"OPEL"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OPEL"],"y":[12424.0]}},"id":"b02fe60a-270a-4d6c-844c-75e8d5e2a8c3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"018066ef-0cc7-4298-a5fc-84b973f2bd0f","type":"ColumnDataSource"},"glyph":{"id":"7ae7d5ef-7a26-4c1f-bbed-625fc7d23ef3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d66da73f-f6ff-46cc-918f-3430431bfe74","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"fuelName":"MITSUBISHI MOTORS CORPORATION"}],"color":["#f22c40"],"fill_alpha":[0.8],"fuelName":["MITSUBISHI MOTORS CORPORATION"],"height":[1222.0],"label":[{"fuelName":"MITSUBISHI MOTORS CORPORATION"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["MITSUBISHI MOTORS CORPORATION"],"y":[611.0]}},"id":"39d80139-d60d-4e30-a05f-45f694048928","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"fuelName":"CHRYSLER"}],"color":["#f22c40"],"fill_alpha":[0.8],"fuelName":["CHRYSLER"],"height":[1965.0],"label":[{"fuelName":"CHRYSLER"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["CHRYSLER"],"y":[982.5]}},"id":"992ca531-a808-49d3-a3fe-2a3b330e2b79","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69adff75-9c26-4b08-9147-d570ccb9a9d5","type":"Rect"},{"attributes":{"plot":{"id":"4a890a87-1389-4a65-9206-115bcc735581","subtype":"Chart","type":"Plot"}},"id":"682ebeb6-3274-4f08-aca8-0a43ec80905f","type":"ResetTool"},{"attributes":{"plot":{"id":"4a890a87-1389-4a65-9206-115bcc735581","subtype":"Chart","type":"Plot"}},"id":"25bb08b9-adc2-4071-b146-f7a33471c572","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"fuelName":"HYUNDAI CZECH"}],"color":["#f22c40"],"fill_alpha":[0.8],"fuelName":["HYUNDAI CZECH"],"height":[2630.0],"label":[{"fuelName":"HYUNDAI CZECH"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["HYUNDAI CZECH"],"y":[1315.0]}},"id":"4343979f-4f74-490d-9a30-023d0a5f7d28","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units": ...

# %% [markdown]
# Foram despresados os combustíveis: BIODIESEL, Hydrogen, M1 (Metanol), PETROL PHEV, HYBRID/PETROL/E por conter uma quantidade insignificante de dados.

# %%
fuelName = []
fuelQuant = []
for i, row in pd_cars["Ft"].value_counts().sort_values().iteritems():
        if (not str(i).isnumeric()):
            fuelName.append(i)
            fuelQuant.append(row)
            print (str(i) + " - "+str(row))

print(len(fuelName))
print(len(fuelQuant))
# Out:
# PETROL-ELECTRIC
