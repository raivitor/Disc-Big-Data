# %% [markdown]
# # Exercise
#
# - Use the previous knowledge to extract information from the European Environment Agency (EEA).
# - Adopt the monitoring co2 emissions [dataset](http://www.eea.europa.eu/data-and-maps/data/co2-cars-emission-11) (**Monitoring of CO2 emissions from passenger cars - Data 2015 - Final data**)

# %%
#%%timeit
import pandas as pd
import numpy as np
from pprint import pprint
pd_cars = pd.read_csv("CO2_passenger_cars_v12_editado2.csv", low_memory = False, error_bad_lines = False, warn_bad_lines = False)
df_cars = pd.DataFrame(pd_cars)

#pd_cars.to_csv("teste.csv")
# Out:
# 1 loop, best of 3: 1.97 s per loop

# %%
print (pd_cars == df_cars)
# Out:
#           id    MS     MP    Mh   Man    MMS    TAN     T    Va    Ve  \
# 0       True  True   True  True  True   True   True  True  True  True
# 1       True  True   True  True  True   True   True  True  True  True
# 2       True  True   True  True  True   True   True  True  True  True
# 3       True  True   True  True  True   True   True  True  True  True
# 4       True  True   True  True  True   True   True  True  True  True
# 5       True  True   True  True  True   True   True  True  True  True
# 6       True  True   True  True  True   True   True  True  True  True
# 7       True  True   True  True  True   True   True  True  True  True
# 8       True  True   True  True  True   True   True  True  True  True
# 9       True  True   True  True  True   True   True  True  True  True
# 10      True  True   True  True  True   True   True  True  True  True
# 11      True  True   True  True  True   True   True  True  True  True
# ...

# %%
fuel = df_cars["Mk"].unique()
fuelType = []
for rowFuel in fuel:
    try:
        if(int(rowFuel)):
            continue
    except:
        fuelType.append(str(rowFuel))
b = sorted(fuelType, key=str.lower)        
#print (b)
pprint (sorted(fuelType))
# Out:
# [' ',
#  ' 137-938',
#  ' Coventry',
#  ' Coventry CV3 4LF',
#  ' ENGLESKA',
#  ' JAPAN',
#  ' KOREA',
#  ' Minato-ku',
#  ' TAJLAND',
#  '-',
#  '00000EN',
#  '00A',
#  '00AA',
#  '00AE',
#  '00AF',
#  '00AG',
#  '00D',
#  '00T',
#  '00U',
#  '00W',
#  '00Y',
#  '01A',
#  '01L',
#  '02A',
#  '02B',
#  '02L',
#  '02V',
#  '02Z',
#  '03A',
#  '03B',
#  '03E',
#  '03F',
#  '03G',
#  '03H',
#  '03L',
#  '03U',
#  '04B',
#  '04E',
#  '04U',
#  '050L',
#  '05D',
#  '05F',
#  '05H',
#  '05KD',
#  '05TROEN',
#  '06C',
#  '06E',
#  '07P',
#  '08E',
#  '09B',
#  '09E',
#  '0A0',
#  '0A1',
#  '0C0',
#  '0F0',
#  '0G-A',
#  '0L0',
#  '0PEL Η VAUXHALL',
#  '0SDA0',
#  '0SDA3',
#  '0SDA4',
#  '0SDCH',
#  '0SDCJ',
#  '0SDCL',
#  '0SDCV',
#  '0SDCY',
#  '0SDG3',
#  '0U',
#  '10G',
#  '10H',
#  '10R',
#  '1211M2',
#  '1211P2',
#  '1212M2',
#  '1212P2',
#  '1241Q2',
#  '124GQ2',
#  '124HQ2',
#  '124KP1',
#  '124KP2',
#  '124LP1',
#  '124NP1',
#  '125GP1',
#  '12S1P1',
#  '12S1P2',
#  '12S2P1',
# ...

# %%
print(len(df_cars["MP"].unique()))
print(len(df_cars["Mh"].unique()))
print(len(df_cars["Man"].unique()))
print(len(df_cars["MMS"].unique()))
print(len(df_cars["T"].unique()))
pprint(df_cars["MP"].value_counts().sort_values())
print("---------------------")
pprint(df_cars["Mh"].value_counts().sort_values())
# Out:
# 15
# 96
# 103
# 689
# 2825
# SUZUKI POOL                 2081
# MITSUBISHI MOTORS           2176
# HONDA MOTOR EUROPE LTD      2767
# TATA MOTORS LTD             7076
# HYUNDAI                     8261
# KIA                         8789
# TOYOTA-DAHAITSU GROUP      13184
# FCA ITALY SPA              16305
# FORD-WERKE GMBH            18454
# RENAULT                    29296
# GENERAL MOTORS             35066
# DAIMLER AG                 42911
# BMW GROUP                  44906
# VW GROUP PC               151540
# Name: MP, dtype: int64
# ---------------------
# TAZZARI                              1
# BLUECAR ITALY                        1
# MICRO VETT                           1
# JIANGLING MOTOR                      1
# LADA FRANCE                          1
# PERODUA                              1
# PAGANI                               1
# MITSUBISHI MOTORS EUROPE             1
# WESTFIELD                            2
# NEVS                                 2
# ...

# %%
for i, row in df_cars["Mk"].value_counts().sort_values().iteritems():
        if(row < 1000 and row > 100):
            print (str(i) + " - "+str(row))
# Out:
# S5DF2F - 105
# J11 - 105
# LADA - 108
# 21 - 110
# FM6FM6BB0027MM5VR2SE61 - 111
# FM6SFM6AJ0097MMVLO5 - 111
# P-J - 112
# FM5SFM5CF0087MM61 - 113
# Fiat - 113
# S5DA2F - 115
# 4 - 116
# S5IO2F - 117
# A01 - 117
# CADILLAC - 118
# 8 - 119
# FM6FM6BB0027MJ7VR2SE - 121
# G - 122
# 3 - 122
# S5DB2F - 124
# 5E - 126
# BMW I - 129
# FM6SFM6AJ0097MMVLO - 135
# SGNFM52T1067MJGI - 135
# MORGAN - 136
# FM6FM6BB0027MJ5VR2SE - 137
# Suzuki - 139
# 7 - 143
# 2 - 148
# S-D - 150
# S4KQ2F - 156
# S5FU2F - 158
# FM5NFM52T1067MM66 - 160
# S5FF2F - 161
# L - 164
# H - 168
# S5KY2F - 176
# LAMBORGHINI - 180
# Citroen - 186
# S5LZ2F - 187
# Volvo - 192
# D - 196
# MCLAREN - 211
# 9 - 214
# S4KW2F - 219
# S5CF2F - 229
# FERRARI - 235
# SD - 244
# Peugeot - 246
# A - 257
# S5CD2F - 259
# LOTUS - 261
# Honda - 262
# ASTON MARTIN - 273
# B - 274
# Porsche - 276
# S5CA2F - 289
# Nissan - 294
# S5CH2F - 296
# S5CC2F - 298
# FIAT - INNOCENTI - 310
# Toyota - 313
# S5AB2F - 334
# TESLA MOTORS - 334
# R - 337
# ...

# %%
np_fuelType = np.array(fuelType)
superArray = [[] for y in range(len(fuelType))] 

for label, row in df_cars.iterrows():
    fuel = row["Ft"]
    index = np.where(np_fuelType == fuel)
    if len(index[0]) > 0:
        superArray[index[0][0]].append(row["e (g/km)"])
        #print (fuel)
    else:
        #print ("Nao deu")
    if(label > 100):
        break
        
#pprint(superArray)
# Out:
#   File "<ipython-input-37-86b3188e5a7f>", line 12
#     if(label > 100):
#      ^
# IndentationError: expected an indented block

# %%
pprint ( df_cars["Mk"].value_counts().sort_values() )
# Out:
# 5N41                             1
# L0H                              1
# 2EKFW                            1
# AS90                             1
# X351                             1
# BW84                             1
# 2R40                             1
# CBDTA12                          1
# CBABC12                          1
# FD7AM014P8X04LLS47MMEM2          1
# AFCFHCX0                         1
# S5CC27                           1
# FW82                             1
# FM6A8009R8X52LLS47MJEM2AN        1
# 4718                             1
# 5LKUPP                           1
# ANXGBW(5Q)                       1
# BZ0R                             1
# AADMA12                          1
# P1AF                             1
# RADICAL SPORTSCARS               1
# 5SDG1                            1
# IVA507001VC                      1
# FM6B1004RB8K3S57MMEM1            1
# SCFCA300X0                       1
# WZ31                             1
# UFBB1E                           1
# ...

# %%
if (fuelType.index('petrol-electric')):
    print("true")
# Out:
# true
